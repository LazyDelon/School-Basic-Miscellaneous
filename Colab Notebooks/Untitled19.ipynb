# %%
numbers = [21, 4, 35, 1, 8, 7, 3, 6, 9]
my_numbers = []

for number in numbers:
    if (number % 2 != 0): 
　　my_numbers.append(number)

print(my_numbers)
# Out:
#   File "<ipython-input-30-0517c63650c0>", line 6
#     my_numbers.append(number)
#                              ^
# IndentationError: expected an indented block
