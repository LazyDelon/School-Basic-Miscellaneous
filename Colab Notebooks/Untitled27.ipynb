# %%
n = int(input("請輸入正整數："))

for i in range(1, n+1):
    if i % 5 ==0:
        continue
    print(i,end=" ")
    

total=n=0
while(n<10):
  n+=1
  total+=n
print(total)
# Out:
# 請輸入正整數：20
# 1 2 3 4 6 7 8 9 11 12 13 14 16 17 18 19 55
