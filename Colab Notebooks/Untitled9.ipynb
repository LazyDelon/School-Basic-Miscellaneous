# %%
# Out:
# 請輸入購物金額: 100000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-09dde58dff95> in <module>()
#       1 money = int(input("請輸入購物金額: "))
#       2
# ----> 3 if (moey>=100000):
#       4
#       5   if(money>=100000):
#
# NameError: name 'moey' is not defined
