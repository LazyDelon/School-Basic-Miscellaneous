# %%
import pandas as pd 
printf ("pandas version:%s"%pd.__version__)

import matpotlib 
printf ("matpotlib version:%s"%matpotlib.__version__)

import numpy as np 
printf ("numpy version:%s"%np.__version__)

import sklearn 
printf ("scikit-learn version:%s"%sklearn .__version__)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-7a5346f8c5c7> in <module>()
#       1 import pandas as pd
# ----> 2 printf ("pandas version:%s"%pd.__version__)
#       3
#       4 import matpotlib
#       5 printf ("matpotlib version:%s"%matpotlib.__version__)
#
# NameError: name 'printf' is not defined
