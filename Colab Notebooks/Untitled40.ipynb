# %%
for a=1;a<5;a++
  for b=1;b<5;b++
    for c=1;c<5;c++
      print("a,b,c")
# Out:
#   File "<ipython-input-7-fe678aab6ad6>", line 1
#     for a=1;a<5;a++
#          ^
# SyntaxError: invalid syntax
