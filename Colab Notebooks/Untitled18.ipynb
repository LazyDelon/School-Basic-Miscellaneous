# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
 
for i in range(1,6):
    for j in range(1,5):
        for k in range(1,7):
            if( i != k ) and (i != j) and (j != k):
                print i,j,k
# Out:
#   File "<ipython-input-1-0517c63650c0>", line 6
#     my_numbers.append(number)
#                              ^
# IndentationError: expected an indented block
