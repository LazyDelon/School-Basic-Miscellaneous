# %%
for name in ['Christopher', 'Susan']:
	print(name)
# Out:
# Christopher
# Susan

# %%
for name in ['Christopher', 'Susan']:
print(name)
# Out:
#   File "<ipython-input-2-330b1b1a855c>", line 2
#     print(name)
#         ^
# IndentationError: expected an indented block
