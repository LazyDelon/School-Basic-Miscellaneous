# %%
print("　　　　　　*")
print("　　　　　 ***")
print("　　　　　*****")
print("　　　　 *******")
print("　　　　*********")
print("　　　 ***********")
print("　　　*************")
print("　　 ***************")
print("　  *****************")
print("　　　　 　***")
print("　　　　　 ***")
print("　　　　   ***")
print("　　　　 　***")
print("　　　　 　***")
# Out:
# 　　　　　　*
# 　　　　　 ***
# 　　　　　*****
# 　　　　 *******
# 　　　　*********
# 　　　 ***********
# 　　　*************
# 　　 ***************
# 　  *****************
# 　　　　 　***
# 　　　　　 ***
# 　　　　   ***
# 　　　　 　***
# 　　　　 　***
