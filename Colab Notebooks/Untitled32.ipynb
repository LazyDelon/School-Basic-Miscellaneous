# %%
if country == 'Canada':
	if province in('Alberta','Nunavut','Yukon'):
		tax = 0.05
	elseif: province == 'Ontario':
		tax = 0.13
	else:
		tax = 0.15
else:
	tax = 0.0
# Out:
#   File "<ipython-input-10-8c7985ec586c>", line 4
#     elseif province == 'Ontario':
#                   ^
# SyntaxError: invalid syntax
